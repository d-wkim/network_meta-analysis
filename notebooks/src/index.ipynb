# %%
with open("./systematic_review.ipynb", "w") as f:
    f.write("")

# %% [markdown]
# <a id="systematic-review"></a>
#
# <h1 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Systematic Review</h1>

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Protocol</h3>

# %%
import ipywidgets as widgets
from IPython.display import display

picos = {
    "population/participation",
    "intervention",
    "comparator(s)",
    "outcome(s)",
    "study design"
}

def app():
    for x in picos:
        w = widgets.Text(description = f"{x}")

# %%
from protocol import app
# Out:
# Traceback (most recent call last):
#
#   File C:\tools\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 1
#     from protocol import app
#
#   File G:\My Drive\network_meta-analysis\app\voila\render\protocol.py:13
#     return widgets.Text(description = f"{x}")
#     ^
# SyntaxError: 'return' outside function

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Search strategy</h3>

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Search</h3>

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Deduplication</h3>

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Screening</h3>

# %% [markdown]
# <a id="outcomes"></a>
#
# <h1 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Data</h1>

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Database</h3>

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Forms</h3>

# %%
import ipywidgets as widgets
from IPython.display import display
import requests
from bs4 import BeautifulSoup as bs4
import re

# inputs are number of rows and columns to automatically generate scripts that output a spreadsheet-like layout of components
import string

def automatic_forms():
    # name
    name = input("Name of form: ")
    name = f"{name}"
    
    # rows
    int_rows = int(input("Number of rows: "))
    rows = range(1, int_rows + 1)

    # columns
    Columns = int(input("Number of columns: "))
    Letters = string.ascii_uppercase[:Columns]
    columns = list(Letters)
        
    def auto_widgets(): # generates the script for the widgets
        for y in columns:
            for x in rows:
                cell = f"{y}{x}"
                xy = widgets.Text()
                w_script = f"{cell} = widgets.Text()" # script for widgets
                print(w_script)
                for label in labels:
                    l_script = f"{cell}.description = {labels}"
                    print(l_script)
                    
    def auto_display(): # generates the script for each row of widgets
        for x in rows:
            cols = []
            for y in columns:
                cell = f"{y}{x}"
                cols.append(cell)
                if len(cols) != 0:
                    items = ", ".join(cols)
                    d_script = f"""R{x} = widgets.HBox(children = [{items.replace("'","")}], layout = {{"width":"100%"}})""" # script for horizontal boxes
                    print(d_script)
    
    def auto_output(): # generates the script for the column of rows 
        R = []
        for x in rows:
            r = f"R{x}"
            R.append(r)
            items = ", ".join(R)
        print(f"""{name} = widgets.VBox(children = [{items.replace("'","")}], layout = {{"width":"100%", "height":"100%"}})\n""")
        print(f"display({name})")

    return auto_widgets(), auto_display(), auto_output()

# %%
automatic_forms()
# Out:
# Name of form:  general
# Number of rows:  5
# Number of columns:  1
# Labels:  "id", "study", "study_design", "subgroups", "outcomes"
# A1 = widgets.Text()
# A1.description = ['"id", "study", "study_design", "subgroups", "outcomes"']
# A2 = widgets.Text()
# A2.description = ['"id", "study", "study_design", "subgroups", "outcomes"']
# A3 = widgets.Text()
# A3.description = ['"id", "study", "study_design", "subgroups", "outcomes"']
# A4 = widgets.Text()
# A4.description = ['"id", "study", "study_design", "subgroups", "outcomes"']
# A5 = widgets.Text()
# A5.description = ['"id", "study", "study_design", "subgroups", "outcomes"']
# R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
# R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
# R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
# R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
# R5 = widgets.HBox(children = [A5], layout = {"width":"100%"})
# ...

# %%
# general
A1 = widgets.Text()
A2 = widgets.Text()
A3 = widgets.Text()
A4 = widgets.Text()
A5 = widgets.Text()
R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
R5 = widgets.HBox(children = [A5], layout = {"width":"100%"})
general = widgets.VBox(children = [R1, R2, R3, R4, R5], layout = {"width":"100%", "height":"100%"})

display(general)

# references
A1 = widgets.Text()
A2 = widgets.Text()
A3 = widgets.Text()
A4 = widgets.Text()
A5 = widgets.Text()
A6 = widgets.Text()
A7 = widgets.Text()
A8 = widgets.Text()
A9 = widgets.Text()
A10 = widgets.Text()

R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
R5 = widgets.HBox(children = [A5], layout = {"width":"100%"})
R6 = widgets.HBox(children = [A6], layout = {"width":"100%"})
R7 = widgets.HBox(children = [A7], layout = {"width":"100%"})
R8 = widgets.HBox(children = [A8], layout = {"width":"100%"})
R9 = widgets.HBox(children = [A9], layout = {"width":"100%"})
R10 = widgets.HBox(children = [A10], layout = {"width":"100%"})

references = widgets.VBox(children = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10], layout = {"width":"100%", "height":"100%"})

display(references)

# characteristics
A1 = widgets.Text()
A2 = widgets.Text()
A3 = widgets.Text()
A4 = widgets.Text()
A5 = widgets.Text()
A6 = widgets.Text()
A7 = widgets.Text()
A8 = widgets.Text()
A9 = widgets.Text()
A10 = widgets.Text()
A11 = widgets.Text()
R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
R5 = widgets.HBox(children = [A5], layout = {"width":"100%"})
R6 = widgets.HBox(children = [A6], layout = {"width":"100%"})
R7 = widgets.HBox(children = [A7], layout = {"width":"100%"})
R8 = widgets.HBox(children = [A8], layout = {"width":"100%"})
R9 = widgets.HBox(children = [A9], layout = {"width":"100%"})
R10 = widgets.HBox(children = [A10], layout = {"width":"100%"})
R11 = widgets.HBox(children = [A11], layout = {"width":"100%"})
characteristics = widgets.VBox(children = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, R11], layout = {"width":"100%", "height":"100%"})

display(characteristics)

# covariates
A1 = widgets.Text() # study ID
A2 = widgets.Text() # age
A3 = widgets.Text() # sex
A4 = widgets.Text() # follow-up duration
R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
covariates = widgets.VBox(children = [R1, R2, R3, R4], layout = {"width":"100%", "height":"100%"})

display(covariates)

# arms

A1 = widgets.Text()
A2 = widgets.Text()
A3 = widgets.Text()
A4 = widgets.Text()
R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
arms = widgets.VBox(children = [R1, R2, R3, R4], layout = {"width":"100%", "height":"100%"})

display(arms)

# results

A1 = widgets.Text()
A2 = widgets.Text()
A3 = widgets.Text()
A4 = widgets.Text()
A5 = widgets.Text()
A6 = widgets.Text()
A7 = widgets.Text()
A8 = widgets.Text()
A9 = widgets.Text()
A10 = widgets.Text()
A11 = widgets.Text()
A12 = widgets.Text()
A13 = widgets.Text()
A14 = widgets.Text()
A15 = widgets.Text()
A16 = widgets.Text()
A17 = widgets.Text()
A18 = widgets.Text()
A19 = widgets.Text()
A20 = widgets.Text()
A21 = widgets.Text()
A22 = widgets.Text()
A23 = widgets.Text()
A24 = widgets.Text()
A25 = widgets.Text()
A26 = widgets.Text()
A27 = widgets.Text()
A28 = widgets.Text()
A29 = widgets.Text()
A30 = widgets.Text()
A31 = widgets.Text()
A32 = widgets.Text()
A33 = widgets.Text()
A34 = widgets.Text()
A35 = widgets.Text()
A36 = widgets.Text()
A37 = widgets.Text()
A38 = widgets.Text()
A39 = widgets.Text()
A40 = widgets.Text()
A41 = widgets.Text()
R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
R5 = widgets.HBox(children = [A5], layout = {"width":"100%"})
R6 = widgets.HBox(children = [A6], layout = {"width":"100%"})
R7 = widgets.HBox(children = [A7], layout = {"width":"100%"})
R8 = widgets.HBox(children = [A8], layout = {"width":"100%"})
R9 = widgets.HBox(children = [A9], layout = {"width":"100%"})
R10 = widgets.HBox(children = [A10], layout = {"width":"100%"})
R11 = widgets.HBox(children = [A11], layout = {"width":"100%"})
R12 = widgets.HBox(children = [A12], layout = {"width":"100%"})
R13 = widgets.HBox(children = [A13], layout = {"width":"100%"})
R14 = widgets.HBox(children = [A14], layout = {"width":"100%"})
R15 = widgets.HBox(children = [A15], layout = {"width":"100%"})
R16 = widgets.HBox(children = [A16], layout = {"width":"100%"})
R17 = widgets.HBox(children = [A17], layout = {"width":"100%"})
R18 = widgets.HBox(children = [A18], layout = {"width":"100%"})
R19 = widgets.HBox(children = [A19], layout = {"width":"100%"})
R20 = widgets.HBox(children = [A20], layout = {"width":"100%"})
R21 = widgets.HBox(children = [A21], layout = {"width":"100%"})
R22 = widgets.HBox(children = [A22], layout = {"width":"100%"})
R23 = widgets.HBox(children = [A23], layout = {"width":"100%"})
R24 = widgets.HBox(children = [A24], layout = {"width":"100%"})
R25 = widgets.HBox(children = [A25], layout = {"width":"100%"})
R26 = widgets.HBox(children = [A26], layout = {"width":"100%"})
R27 = widgets.HBox(children = [A27], layout = {"width":"100%"})
R28 = widgets.HBox(children = [A28], layout = {"width":"100%"})
R29 = widgets.HBox(children = [A29], layout = {"width":"100%"})
R30 = widgets.HBox(children = [A30], layout = {"width":"100%"})
R31 = widgets.HBox(children = [A31], layout = {"width":"100%"})
R32 = widgets.HBox(children = [A32], layout = {"width":"100%"})
R33 = widgets.HBox(children = [A33], layout = {"width":"100%"})
R34 = widgets.HBox(children = [A34], layout = {"width":"100%"})
R35 = widgets.HBox(children = [A35], layout = {"width":"100%"})
R36 = widgets.HBox(children = [A36], layout = {"width":"100%"})
R37 = widgets.HBox(children = [A37], layout = {"width":"100%"})
R38 = widgets.HBox(children = [A38], layout = {"width":"100%"})
R39 = widgets.HBox(children = [A39], layout = {"width":"100%"})
R40 = widgets.HBox(children = [A40], layout = {"width":"100%"})
R41 = widgets.HBox(children = [A41], layout = {"width":"100%"})
results = widgets.VBox(children = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, R11, R12, R13, R14, R15, R16, R17, R18, R19, R20, R21, R22, R23, R24, R25, R26, R27, R28, R29, R30, R31, R32, R33, R34, R35, R36, R37, R38, R39, R40, R41], layout = {"width":"100%", "height":"100%"})

display(results)

# risk of bias

A1 = widgets.Text()
A2 = widgets.Text()
A3 = widgets.Text()
A4 = widgets.Text()
A5 = widgets.Text()
A6 = widgets.Text()
A7 = widgets.Text()
A8 = widgets.Text()
A9 = widgets.Text()
A10 = widgets.Text()
A11 = widgets.Text()
A12 = widgets.Text()
A13 = widgets.Text()
A14 = widgets.Text()
A15 = widgets.Text()
A16 = widgets.Text()
A17 = widgets.Text()
A18 = widgets.Text()
A19 = widgets.Text()
A20 = widgets.Text()
A21 = widgets.Text()
A22 = widgets.Text()
A23 = widgets.Text()
B1 = widgets.Text()
B2 = widgets.Text()
B3 = widgets.Text()
B4 = widgets.Text()
B5 = widgets.Text()
B6 = widgets.Text()
B7 = widgets.Text()
B8 = widgets.Text()
B9 = widgets.Text()
B10 = widgets.Text()
B11 = widgets.Text()
B12 = widgets.Text()
B13 = widgets.Text()
B14 = widgets.Text()
B15 = widgets.Text()
B16 = widgets.Text()
B17 = widgets.Text()
B18 = widgets.Text()
B19 = widgets.Text()
B20 = widgets.Text()
B21 = widgets.Text()
B22 = widgets.Text()
B23 = widgets.Text()
R1 = widgets.HBox(children = [A1], layout = {"width":"100%"})
R1 = widgets.HBox(children = [A1, B1], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2], layout = {"width":"100%"})
R2 = widgets.HBox(children = [A2, B2], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3], layout = {"width":"100%"})
R3 = widgets.HBox(children = [A3, B3], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4], layout = {"width":"100%"})
R4 = widgets.HBox(children = [A4, B4], layout = {"width":"100%"})
R5 = widgets.HBox(children = [A5], layout = {"width":"100%"})
R5 = widgets.HBox(children = [A5, B5], layout = {"width":"100%"})
R6 = widgets.HBox(children = [A6], layout = {"width":"100%"})
R6 = widgets.HBox(children = [A6, B6], layout = {"width":"100%"})
R7 = widgets.HBox(children = [A7], layout = {"width":"100%"})
R7 = widgets.HBox(children = [A7, B7], layout = {"width":"100%"})
R8 = widgets.HBox(children = [A8], layout = {"width":"100%"})
R8 = widgets.HBox(children = [A8, B8], layout = {"width":"100%"})
R9 = widgets.HBox(children = [A9], layout = {"width":"100%"})
R9 = widgets.HBox(children = [A9, B9], layout = {"width":"100%"})
R10 = widgets.HBox(children = [A10], layout = {"width":"100%"})
R10 = widgets.HBox(children = [A10, B10], layout = {"width":"100%"})
R11 = widgets.HBox(children = [A11], layout = {"width":"100%"})
R11 = widgets.HBox(children = [A11, B11], layout = {"width":"100%"})
R12 = widgets.HBox(children = [A12], layout = {"width":"100%"})
R12 = widgets.HBox(children = [A12, B12], layout = {"width":"100%"})
R13 = widgets.HBox(children = [A13], layout = {"width":"100%"})
R13 = widgets.HBox(children = [A13, B13], layout = {"width":"100%"})
R14 = widgets.HBox(children = [A14], layout = {"width":"100%"})
R14 = widgets.HBox(children = [A14, B14], layout = {"width":"100%"})
R15 = widgets.HBox(children = [A15], layout = {"width":"100%"})
R15 = widgets.HBox(children = [A15, B15], layout = {"width":"100%"})
R16 = widgets.HBox(children = [A16], layout = {"width":"100%"})
R16 = widgets.HBox(children = [A16, B16], layout = {"width":"100%"})
R17 = widgets.HBox(children = [A17], layout = {"width":"100%"})
R17 = widgets.HBox(children = [A17, B17], layout = {"width":"100%"})
R18 = widgets.HBox(children = [A18], layout = {"width":"100%"})
R18 = widgets.HBox(children = [A18, B18], layout = {"width":"100%"})
R19 = widgets.HBox(children = [A19], layout = {"width":"100%"})
R19 = widgets.HBox(children = [A19, B19], layout = {"width":"100%"})
R20 = widgets.HBox(children = [A20], layout = {"width":"100%"})
R20 = widgets.HBox(children = [A20, B20], layout = {"width":"100%"})
R21 = widgets.HBox(children = [A21], layout = {"width":"100%"})
R21 = widgets.HBox(children = [A21, B21], layout = {"width":"100%"})
R22 = widgets.HBox(children = [A22], layout = {"width":"100%"})
R22 = widgets.HBox(children = [A22, B22], layout = {"width":"100%"})
R23 = widgets.HBox(children = [A23], layout = {"width":"100%"})
R23 = widgets.HBox(children = [A23, B23], layout = {"width":"100%"})
rob2 = widgets.VBox(children = [R1, R2, R3, R4, R5, R6, R7, R8, R9, R10, R11, R12, R13, R14, R15, R16, R17, R18, R19, R20, R21, R22, R23], layout = {"width":"100%", "height":"100%"})

display(rob2)

# %%
pages = [general, references, characteristics, covariates, arms, results, rob2]
titles = ["general", "references", "characteristics", "covariates", "arms", "results", "risk of bias"]
tab = widgets.Tab(
    children = pages,
    titles = titles
)

display(tab)

# %%
<h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Extraction</h3>
# Out:
#   Cell In[24], line 99
#     <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Extraction</h3>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h3 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Transformation</h3>

# %% [markdown]
# <a id="outcomes"></a>
#
# <h1 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Network Meta-Analysis</h1>
# <h2 align="center" style="font-family:Times New Roman; font-variant:small-caps;">Web Application</h2>

# %%
from src import database, forms, extraction, transformation
# Out:
# Traceback (most recent call last):
#
#   File C:\tools\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[27], line 1
#     from src import database, forms, extraction, transformation
#
#   File G:\My Drive\network_meta-analysis\binder\voila\render\src\__init__.py:64
#     globals()[filename] = pathimport os
#                                      ^
# SyntaxError: invalid syntax

# %%
url = "https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/refs/heads/master/systematic_review/search/records.csv"
df = pd.read_csv(url, encoding = "utf-8")

a, a1 =  widgets.IntText(description = "ID", layout = {"width":"20%"}),\
         widgets.IntSlider(value = 0, readout = False, min = 1, max = len(df)-1, layout = {"width":"70%"}),

link = widgets.jslink((a, "value"),(a1,"value"))
out = widgets.Output()


# forms components: 
A = widgets.HBox(children = [a, a1])
b = widgets.Text(description = "study ", layout = {"width": "50%"}) # study
c = widgets.Text(description = "subgroup", layout = {"width": "50%"})
d = widgets.Text(value = "", description = "author(s) ", layout = {"width": "90%"}) # authors
e = widgets.Text(value = "", description = "title ", layout = {"width": "90%"}) # title
f = widgets.Text(value = "", description = "abstract ", layout = {"width": "91.5%", "height": "300px"}) # abstract
g = widgets.Text(value = "", description = "year ", layout = {"width": "90%"}) # year
h = widgets.Text(value = "", description = "journal ", layout = {"width": "90%"}) # journal
i = widgets.Text(description = "source", layout = {"width": "50%"})
j = widgets.Text(value = "", description = "DOI ", layout = {"width": "90%"}) # doi
k = widgets.Text(value = "", description = "URL ", layout = {"width": "90%"}) # url

columns = ["study", "subgroup", "authors", "title", "abstract", "year", "journal", "source", "doi", "url"]
wid = [b, c, d, e, f, g, h, i, j, k]

mapping = dict(zip(columns, wid))

def update(change):
    id = df.loc[df["id"] == a.value]
    study = df.loc[df["id"] == a.value, "study"]
    subgroup =  df.loc[df["id"] == a.value, "subgroup"]
    authors =  df.loc[df["id"] == a.value, "authors"]
    title =  df.loc[df["id"] == a.value, "title"]
    abstract =  df.loc[df["id"] == a.value, "abstract"]
    year =  df.loc[df["id"] == a.value, "year"]
    journal =  df.loc[df["id"] == a.value, "journal"]
    source =  df.loc[df["id"] == a.value, "source"]
    doi =  df.loc[df["id"] == a.value, "doi"]
    url =  df.loc[df["id"] == a.value, "doi_url"]
    
    if a.value > 0:
        b.value = str(study.iloc[0])
        c.value = str(subgroup.iloc[0])
        d.value = str(authors.iloc[0])
        e.value = str(title.iloc[0])
        f.value = str(abstract.iloc[0])
        g.value = str(year.iloc[0])
        h.value = str(journal.iloc[0])
        i.value = str(source.iloc[0])
        j.value = str(doi.iloc[0])
        k.value = str(url.iloc[0])    

a.observe(update, names = "value")
display(A, b, c, d, e, f, g, h, i, j, k)
df = df.sort_values(by = 'id')
df.head()    

yes = widgets.Button(
    value = "Yes", 
    description = "Yes", 
    icon = "check", 
    button_style = "", 
    layout = {
        "width":"25%"})

maybe = widgets.Button(
    value = "Maybe", 
    description = "Maybe", 
    icon = "", 
    button_style = "")

no = widgets.Button(
    value = "No", 
    description = "No", 
    icon = "times", 
    button_style = "")

save = widgets.Button(
    value = "Save", 
    description = "Save", 
    icon = "floppy-o", 
    button_style = "")

out = widgets.Output()

buttons = widgets.HBox([yes, maybe, no, save])
display(buttons, out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 url = "https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/refs/heads/master/systematic_review/search/records.csv"
# ----> 2 df = pd.read_csv(url, encoding = "utf-8")
#       3
#       4 a, a1 =  widgets.IntText(description = "ID", layout = {"width":"20%"}),\
#       5          widgets.IntSlider(value = 0, readout = False, min = 1, max = len(df)-1, layout = {"width":"70%"}),
#
# NameError: name 'pd' is not defined

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/refs/heads/master/systematic_review/search/records.csv"
df = pd.read_csv(url, encoding = "utf-8")
df.head()
# Out:
#    Unnamed: 0    id  source_id             study subgroup  \
# 0         383  1153       1143      Sun K (2004)       AT
# 1         382   956        940     Noh JH (2011)       AT
# 2        1229   961        948  Taylor DW (2011)       AT
# 3         381   891        891     Noh JH (2012)       AT
# 4         703   892        897     Noh JH (2012)       AT
#
#                                              authors first_author  \
# 0  Sun K, Tang JW, Xu Q, Liu XY, Zhou LG, Hao YQ,...        Sun K
# 1              Noh JH, Yi SR, Song SJ, Kim SW, Kim W       Noh JH
# 2  Taylor DW, Petrera M, Hendry M, Theodoropoulos JS    Taylor DW
# 3             Noh JH, Yang BG, Yi SR, Roh YH, Lee JS       Noh JH
# 4             Noh JH, Yang BG, Yi SR, Roh YH, Lee JS       Noh JH
#
#                                                title  \
# 0  [A prospective study of the anterior cruciate ...
# 1  Comparison between hamstring autograft and fre...
# ...

# %%
df = df.drop(columns = [df.columns[0], 'authors', 'source_id', 'short_title', 'title+author+year', 'title+year'])
studies = df[["id","first_author","second_author","num_authors", "year"]]

# %%
import numpy as np

import numpy as np
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# assumes df already exists and has:
# id, first_author, second_author, num_authors, year, doi

df["id"] = df["id"].astype(int)
df = df.set_index("id", drop=False)

df["year_str"] = df["year"].astype("Int64").astype(str)

df["study_label"] = np.select(
    [
        df["num_authors"] == 1,
        df["num_authors"] == 2,
        df["num_authors"] > 2,
    ],
    [
        df["first_author"] + " (" + df["year_str"] + ")",
        df["first_author"] + " & " + df["second_author"] + " (" + df["year_str"] + ")",
        df["first_author"] + " et al. (" + df["year_str"] + ")",
    ],
    default=df["first_author"] + " (" + df["year_str"] + ")",
)

df["doi_url"] = np.where(
    df["doi"].notna() & (df["doi"].astype(str).str.strip() != ""),
    "https://doi.org/" + df["doi"].astype(str),
    "",
)

df["study_label_Text"] = np.where(
    df["doi_url"] != "",
    '<a href="' + df["doi_url"] + '" target="_blank">'
    + df["study_label"]
    + "<sup>"
    + df["id"].astype(str)
    + "</sup></a>",
    df["study_label"] + "<sup>" + df["id"].astype(str) + "</sup>",
)

id_widget = widgets.IntSlider(
    value=int(df.index.min()),
    min=int(df.index.min()),
    max=int(df.index.max())
)

study_widget = widgets.Text()

def update_study(change=None):
    row_id = id_widget.value
    study_widget.value = df.loc[row_id, "study_label_Text"]

id_widget.observe(update_study, names="value")

update_study()

display(id_widget, study_widget)
# Out:
# IntSlider(value=1, max=1563, min=1)
# HTML(value='<a href="https://doi.org/10.1186/s13018-026-06776-6" target="_blank">Liu et al. (2026)<sup>1</sup>…

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd

def form():
    url = "https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/refs/heads/master/systematic_review/search/records.csv"
    df = pd.read_csv(url, encoding = "utf-8")
    
    a, a1 =  widgets.IntText(description = "ID", layout = {"width":"20%"}),\
             widgets.IntSlider(value = 0, readout = False, min = 1, max = len(df)-1, layout = {"width":"70%"}),
    
    link = widgets.jslink((a, "value"),(a1,"value"))
    out = widgets.Output()
    
    # design 
    A = widgets.HBox(children = [a, a1])
    b = widgets.Text(description = "study ", layout = {"width": "100%"}) # study
    c = widgets.Text(description = "subgroup", layout = {"width": "100%"})
    d = widgets.Text(value = "", description = "author(s) ", layout = {"width": "90%"}) # authors
    e = widgets.Text(value = "", description = "title ", layout = {"width": "90%"}) # title
    f = widgets.Text(value = "", description = "abstract ", layout = {"width": "91.5%", "height": "300px"}) # abstract
    g = widgets.Text(value = "", description = "year ", layout = {"width": "90%"}) # year
    h = widgets.Text(value = "", description = "journal ", layout = {"width": "90%"}) # journal
    i = widgets.Text(description = "source", layout = {"width": "50%"})
    j = widgets.Text(value = "", description = "DOI ", layout = {"width": "90%"}) # doi
    k = widgets.Text(value = "", description = "URL ", layout = {"width": "90%"}) # url
    
    columns = ["study", "subgroup", "author", "title", "abstract", "year", "journal", "source", "doi", "url"]
    wid = [b, c, d, e, f, g, h, i, j, k]
    
    mapping = dict(zip(columns, wid))
    
    def update(change):
        id = df.loc[df["id"] == a.value]
        study = df.loc[df["id"] == a.value, "study"]
        subgroup =  df.loc[df["id"] == a.value, "subgroup"]
        authors =  df.loc[df["id"] == a.value, "first_author"]
        title =  df.loc[df["id"] == a.value, "title"]
        abstract =  df.loc[df["id"] == a.value, "abstract"]
        year =  df.loc[df["id"] == a.value, "year"]
        journal =  df.loc[df["id"] == a.value, "journal"]
        source =  df.loc[df["id"] == a.value, "source"]
        doi =  df.loc[df["id"] == a.value, "doi"]
        url =  df.loc[df["id"] == a.value, "doi_url"]
        
        if a.value > 0:
            b.value = str(study.iloc[0])
            c.value = str(subgroup.iloc[0])
            d.value = str(authors.iloc[0])
            e.value = str(title.iloc[0])
            f.value = str(abstract.iloc[0])
            g.value = str(year.iloc[0])
            h.value = str(journal.iloc[0])
            i.value = str(source.iloc[0])
            j.value = str(doi.iloc[0])
            k.value = str(url.iloc[0])    
    
    a.observe(update, names = "value")
    bcdj = widgets.VBox([b, c, d, j], layout = {"width":"35%"})
    ghik = widgets.VBox([g, h, i, k], layout = {"width":"55%"})
    hbox = widgets.HBox([bcdj, ghik], layout = {"width":"100%"})
#   display(widgets.VBox([A, hbox, e, f]))
    display(widgets.VBox([A, hbox, e, f]))
    form = widgets.VBox([A, hbox, e, f])
    return forms
 

def result():
    yes = widgets.Button(
        value = "Yes", 
        description = "Yes", 
        icon = "check", 
        button_style = "success", 
        layout = {
            "width":"100%"})
    
    maybe = widgets.Button(
        value = "Maybe", 
        description = "Maybe", 
        icon = "", 
        button_style = "warning")
    
    no = widgets.Button(
        value = "No", 
        description = "No", 
        icon = "times", 
        button_style = "danger")
    
    save = widgets.Button(
        value = "Save", 
        description = "Save", 
        icon = "floppy-o", 
        button_style = "info")
    
    out = widgets.Output()
    
    buttons = widgets.HBox([yes, maybe, no, save])
#    display(buttons, out)
    return buttons

def main():
    form()

if __name__ == "__main__":
    display(forms, buttons)

# %%
display(form, buttons)
# Out:
# <function __main__.form()>
# ...

# %% [markdown]
# ② Create widgets for each column.

# %%
a = widgets.Text(description = "ID") # column A becomes primary key, "id"

# %%
b = widgets.Text() # since Text widgets accept int and floats we'll define all as Text for now
c = widgets.Text()
d = widgets.Text()
e = widgets.Text()

# %%
mapping = {
    "A": a,
    "B": b,
    "C": c,
    "D": d,
    "E": e
}

# %%
def row(change = None):
    row = a.value
    for column, widget in mapping.items():
        widget.value  = df.loc[row, column]

# %%
Save = widgets.Button(icon = "save")
def save(button = None):
    row = a.value

    for column, widget in mapping.items():
        widget.value = df.loc[row, column]

    with out:
        out.clear_output()
        display(df)

    pd.to_csv("./data.csv", encoding = "utf-8")

a.observe(row, "values")
Save.on_click(save)

row()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\tools\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...
