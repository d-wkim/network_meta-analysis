# %% [markdown]
# # Network Meta-Analysis

# %% [markdown]
# **Import datasets after extraction and transformation**.

# %%
import pandas as pd
csv = ["continuous", "pivot_shift", "lachman"]
for x in csv:
    df = pd.read_csv(f"./data/{x}.csv", encoding = "utf-8")
    globals()[x] = df

# %% [markdown]
# ### Continuous data

# %%
df = continuous.fillna("")
df.set_index(keys = ["id"], inplace=True)
df = df.drop(columns = ["min", "q1", "median", "q3", "max"])
             
ikdc_subjective = df[df["outcome"] == "ikdc"]
ikdc.to_csv("./data/ikdc_subjective.csv", encoding = "utf-8")

lysholm = df[df["outcome"] == "lysholm"]
ikdc.to_csv("./data/lysholm.csv", encoding = "utf-8")

tegner = df[df["outcome"] == "tegner"]
ikdc.to_csv("./data/tegner.csv", encoding = "utf-8")

instrumented_laxity = df[df["outcome"] == "instrumented_laxity"]
ikdc.to_csv("./data/instrumented_laxity.csv", encoding = "utf-8")

# %%
# create group number within each study/outcome
dfs = {
    "ikdc_subjective": ikdc_subjective, 
    "lysholm": lysholm, 
    "tegner": tegner, 
    "instrumented_laxity": instrumented_laxity
}

for name, df in dfs.items():
    df["group"] = df.groupby(["study"]).cumcount() + 1
    
    # reshape
    wide = (
        df.pivot(
            index= "study",
            columns="group",
            values=["subgroup", "n", "mean", "sd"]
        )
    )
    
    # flatten column names
    wide.columns = [
        f"{name}{group}" if name != "subgroup" else f"treat{group}"
        for name, group in wide.columns
    ]
    
    # rename variables
    wide = (
        wide.rename(columns={
            "n1": "n1",
            "mean1": "m1",
            "sd1": "sd1",
            "n2": "n2",
            "mean2": "m2",
            "sd2": "sd2",
        })
        .reset_index()
    )

    wide["n1"] = wide["n1"].astype(int)
    wide["n2"] = wide["n2"].astype(int)
    wide["sd1"] = wide["sd1"].astype(float)
    wide["sd2"] =wide["sd2"].astype(float)
    wide["m1"] = wide["m1"].astype(float)
    wide["m2"] = wide["m2"].astype(float)
    
    import os
    os.makedirs(f"./analysis", exist_ok = True)
    wide.to_csv(f"./analysis/{name}.csv", encoding = "utf-8")
    globals()[name] = wide

# %%
wide.head()
# Out:
# Empty DataFrame
# Columns: [study]
# Index: []

# %%
import numpy as np

# Standardized Mean Difference (SMD)
def SMD(n1, n2, m1, m2, sd1, sd2):
    sd = (
        (((n1 - 1) * sd1**2) + ((n2 - 1) * sd2**2))
        / (n1 + n2 - 2)
    )
    sp = np.sqrt(sd)
    return round((np.abs(m1 - m2) / sp), 3)


# Standard Error of the Standardized Mean Difference (SMD)
def SE(n1, n2, smd):
    se = np.sqrt(
        (n1 + n2)/(n1*n2)
        + smd**2/(2*(n1+n2-2))
    )

    se = round(se, 3)
    return se

# %%
df = ikdc_subjective
df["smd"] = SMD(df["n1"], df["n2"],df["m1"], df["m2"],df["sd1"], df["sd2"])
df["se"] = SE(df["n1"], df["n2"], df["smd"])

df.to_csv(f"./analysis/ikdc_subjective.csv")
df.head()
# Out:
#                     study treat1 treat2  n1  n2  m1  m2  sd1  sd2  group  \
# 0      Barié et al., 2020   BPTB     QT  43  43  91  92    7   11      1
# 1         Bi et al., 2018     HT    PLT  62  62  90  89    7    8      1
# 2  Björnsson et al., 2016   BPTB     HT  61  86  67  74   20   18      1
# 3    Bottoni et al., 2015     HT     TA  44  36  79  81   24   23      1
# 4       Butt et al., 2024     HT    PLT  30  30  89  89    5    9      1
#
#      smd     se
# 0  0.108  0.216
# 1  0.133  0.180
# 2  0.371  0.169
# 3  0.085  0.225
# 4  0.000  0.258

# %%
df = pd.read_csv("./data/lysholm.csv", encoding = "utf-8")
df = lysholm.fillna("")
df["smd"] = SMD(df["n1"], df["n2"],df["m1"], df["m2"],df["sd1"], df["sd2"])
df["se"] = SE(df["n1"], df["n2"], df["smd"])

df.to_csv(f"./analysis/lysholm.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   study   33 non-null     str
#  1   treat1  33 non-null     str
#  2   treat2  33 non-null     str
#  3   n1      33 non-null     int64
#  4   n2      33 non-null     int64
#  5   m1      33 non-null     int64
#  6   m2      33 non-null     int64
#  7   sd1     33 non-null     int64
#  8   sd2     33 non-null     int64
#  9   smd     33 non-null     float64
#  10  se      33 non-null     float64
# dtypes: float64(2), int64(6), str(3)
# memory usage: 3.8 KB

# %%
df["smd"] = SMD(df["n1"], df["n2"],df["m1"], df["m2"],df["sd1"], df["sd2"])
df["se"] = SE(df["n1"], df["n2"], df["smd"])

df.to_csv(f"./analysis/tegner.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   study   23 non-null     str
#  1   treat1  23 non-null     str
#  2   treat2  23 non-null     str
#  3   n1      23 non-null     int64
#  4   n2      23 non-null     int64
#  5   m1      23 non-null     int64
#  6   m2      23 non-null     int64
#  7   sd1     23 non-null     int64
#  8   sd2     23 non-null     int64
#  9   smd     22 non-null     float64
#  10  se      22 non-null     float64
# dtypes: float64(2), int64(6), str(3)
# memory usage: 2.7 KB

# %%
df = instrumented_laxity.fillna("")
df["smd"] = SMD(df["n1"], df["n2"],df["m1"], df["m2"],df["sd1"], df["sd2"])
df["se"] = SE(df["n1"], df["n2"], df["smd"])

df.to_csv(f"./analysis/instrumented_laxity.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   study   34 non-null     str
#  1   treat1  34 non-null     str
#  2   treat2  34 non-null     str
#  3   n1      34 non-null     int64
#  4   n2      34 non-null     int64
#  5   m1      34 non-null     int64
#  6   m2      34 non-null     int64
#  7   sd1     34 non-null     int64
#  8   sd2     34 non-null     int64
#  9   smd     29 non-null     float64
#  10  se      29 non-null     float64
# dtypes: float64(2), int64(6), str(3)
# memory usage: 3.9 KB
